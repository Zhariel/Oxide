# %% [markdown]
# # Imports

# %%
import matplotlib.pyplot as plt
import numpy as np
from ruster import Ruster
import time
import sys
import os

color_1 = "salmon"
color_2 = "deepskyblue"
color_3 = "lightgreen"

r = Ruster(path="C:\\Users\\Revive\\PycharmProjects\\Rust_Native_ML\\rust\\PerceptronLib\\target\\release\\PerceptronLib.dll")

print(r.sum([1, 2, 3]))
# Out:
# 6

# %% [markdown]
# # Cas de tests, rendu 2

# %% [markdown]
# ## Classification

# %% [markdown]
# ### Linear Simple :
#         Linear Model : OK
#         MLP (2, 1)   : OK

# %%
X = np.array([
      [1, 1],
      [2, 3],
      [3, 3]
])
Y = np.array([
      1,
      -1,
      -1
])

# %%
plt.scatter(X[0, 0], X[0, 1], color='blue', s=50)
plt.scatter(X[1:3,0], X[1:3,1], color='red', s=50)
plt.show()
plt.clf()

# %% [markdown]
# ### RBF avec Représentants

# %%
x = X.flatten().tolist()

nb_clusters = 2
ndim = 2

native_clusters = r.init_clusters(x, nb_clusters, ndim)

clusters = r.npify(native_clusters, nb_clusters*ndim)
print(clusters)

plt.scatter(clusters[0], clusters[1], color='lightgrey', s=1000)
plt.scatter(clusters[2], clusters[3], color='lightgrey', s=1000)

r.k_means(x, native_clusters, nb_clusters, ndim)

clusters = r.npify(native_clusters, nb_clusters*ndim)
print(clusters)

r.destroy(native_clusters, nb_clusters*ndim)

plt.scatter(clusters[0], clusters[1], color='lightgreen', s=400)
plt.scatter(clusters[2], clusters[3], color='lightgreen', s=400)
plt.scatter(X[0, 0], X[0, 1], color='blue', s=50)
plt.scatter(X[1:3,0], X[1:3,1], color='red', s=50)
plt.show()
plt.clf()
# Out:
# [1. 1. 2. 3.]
# [1.  1.  2.5 3. ]

# %%
clusters = np.array([1.0,  1.0,  2.5, 3.0 ])
Y = np.array([
    1,
    -1
])

model_size = 2
native_model = r.create_linear_model(model_size)
model = r.npify(native_model, model_size+1)
print(model)

points_x1_blue = []
points_x2_blue = []
points_x1_red = []
points_x2_red = []

for _ in range(20):
    points_x1_blue = []
    points_x2_blue = []
    points_x1_red = []
    points_x2_red = []
    for i in np.arange(1.0, 3.1, 0.07):
        for j in np.arange(1.0, 3.1, 0.07):
            predict = r.predict_linear_model_classification(native_model, np.array([i, j], float), (model_size+1))
            if predict == 1.0:
                points_x1_blue.append(i)
                points_x2_blue.append(j)
            elif predict == -1.0:
                points_x1_red.append(i)
                points_x2_red.append(j)
    
    r.train_rosenblatt_linear_model(native_model, clusters, Y, model_size+1, 20, 0.01)
    model = r.npify(native_model, model_size+1)

plt.scatter(points_x1_blue, points_x2_blue, c=color_1)
plt.scatter(points_x1_red, points_x2_red, c=color_2)
plt.scatter(clusters[0], clusters[1], color='lightgreen', s=400)
plt.scatter(clusters[2], clusters[3], color='lightgreen', s=400)
plt.scatter(X[0, 0], X[0, 1], color='blue', s=50)
plt.scatter(X[1:3,0], X[1:3,1], color='red', s=50)
plt.show()

print(_)
print(clusters)
print(model)

r.destroy(native_model, model_size)
# Out:
# [0.77646923 0.89073515 0.57144666]
# 19
# [1.  1.  2.5 3. ]
# [ 0.47646946  0.14073502 -0.32855335]

# %% [markdown]
# ### Linear Multiple :
#         Linear Model : OK
#         MLP (2, 1)   : OK

# %%
X = np.concatenate([np.random.random((50,2)) * 0.9 + np.array([1, 1]), np.random.random((50,2)) * 0.9 + np.array([2, 2])])
Y = np.concatenate([np.ones((50, 1)), np.ones((50, 1)) * -1.0])

# %%
plt.scatter(X[0:50, 0], X[0:50, 1], color='blue')
plt.scatter(X[50:100,0], X[50:100,1], color='red')
plt.show()
plt.clf()

# %% [markdown]
# ### RBF avec Représentants

# %%
x = X.flatten().tolist()

nb_clusters = 2
ndim = 2

native_clusters = r.init_clusters(x, nb_clusters, ndim)

clusters = r.npify(native_clusters, nb_clusters*ndim)
print(clusters)

plt.scatter(clusters[0], clusters[1], color='lightgrey', s=1000)
plt.scatter(clusters[2], clusters[3], color='lightgrey', s=1000)

r.k_means(x, native_clusters, nb_clusters, ndim)

clusters = r.npify(native_clusters, nb_clusters*ndim)
print(clusters)

r.destroy(native_clusters, nb_clusters*ndim)

plt.scatter(clusters[0], clusters[1], color='lightgreen', s=400)
plt.scatter(clusters[2], clusters[3], color='lightgreen', s=400)
plt.scatter(X[0:50, 0], X[0:50, 1], color='blue')
plt.scatter(X[50:100,0], X[50:100,1], color='red')
plt.show()
plt.clf()
# Out:
# [2.0459867 2.862967  1.8908715 1.0294696]
# [2.4625368 2.4155977 1.4206557 1.4490447]

# %%
clusters = np.array([2.4625368, 2.4155977, 1.4206557, 1.4490447])
Y = np.array([
    1,
    -1
])

model_size = 2
native_model = r.create_linear_model(model_size)
model = r.npify(native_model, model_size+1)
print(model)

points_x1_blue = []
points_x2_blue = []
points_x1_red = []
points_x2_red = []

for _ in range(20):
    points_x1_blue = []
    points_x2_blue = []
    points_x1_red = []
    points_x2_red = []
    for i in np.arange(1.0, 3.0, 0.07):
        for j in np.arange(1.0, 3.0, 0.07):
            predict = r.predict_linear_model_classification(native_model, np.array([i, j], float), (model_size+1))
            if predict == 1.0:
                points_x1_blue.append(i)
                points_x2_blue.append(j)
            elif predict == -1.0:
                points_x1_red.append(i)
                points_x2_red.append(j)
    
    r.train_rosenblatt_linear_model(native_model, clusters, Y, model_size+1, 20, 0.01)
    model = r.npify(native_model, model_size+1)

plt.scatter(points_x1_blue, points_x2_blue, c=color_1)
plt.scatter(points_x1_red, points_x2_red, c=color_2)
plt.scatter(clusters[0], clusters[1], color='lightgreen', s=400)
plt.scatter(clusters[2], clusters[3], color='lightgreen', s=400)
plt.scatter(X[0:50, 0], X[0:50, 1], color='blue')
plt.scatter(X[50:100,0], X[50:100,1], color='red')
plt.show()

print(_)
print(clusters)
print(model)

r.destroy(native_model, model_size)
# Out:
# [-0.33083987  0.7012725   0.04731178]
# 19
# [2.4625368 2.4155977 1.4206557 1.4490447]
# [-0.49083996  0.47396755 -0.18453537]

# %% [markdown]
# ### XOR :
#         Linear Model    : KO
#         MLP (2, 2, 1)   : OK

# %%
X = np.array([[1, 0], [0, 1], [0, 0], [1, 1]])
Y = np.array([1, 1, -1, -1])

# %%
plt.scatter(X[0:2, 0], X[0:2, 1], color='blue')
plt.scatter(X[2:4,0], X[2:4,1], color='red')
plt.show()
plt.clf()

# %% [markdown]
# ### Cross :
#         Linear Model    : KO
#         MLP (2, 4, 1)   : OK

# %%
X = np.random.random((500, 2)) * 2.0 - 1.0
Y = np.array([1 if abs(p[0]) <= 0.3 or abs(p[1]) <= 0.3 else -1 for p in X])

# %%
plt.scatter(np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]] == 1, enumerate(X)))))[:,0], np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]] == 1, enumerate(X)))))[:,1], color='blue')
plt.scatter(np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]] == -1, enumerate(X)))))[:,0], np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]] == -1, enumerate(X)))))[:,1], color='red')
plt.show()
plt.clf()

# %% [markdown]
# ### Multi Linear 3 classes :
#         Linear Model x3 : OK
#         MLP (2, 3)      : OK

# %%
X = np.random.random((500, 2)) * 2.0 - 1.0
Y = np.array([[1, 0, 0] if -p[0] - p[1] - 0.5 > 0 and p[1] < 0 and p[0] - p[1] - 0.5 < 0 else 
              [0, 1, 0] if -p[0] - p[1] - 0.5 < 0 and p[1] > 0 and p[0] - p[1] - 0.5 < 0 else 
              [0, 0, 1] if -p[0] - p[1] - 0.5 < 0 and p[1] < 0 and p[0] - p[1] - 0.5 > 0 else 
              [0, 0, 0]for p in X])
X = X[[not np.all(arr == [0, 0, 0]) for arr in Y]]
Y = Y[[not np.all(arr == [0, 0, 0]) for arr in Y]]

# %%
plt.scatter(np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][0] == 1, enumerate(X)))))[:,0], np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][0] == 1, enumerate(X)))))[:,1], color='blue')
plt.scatter(np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][1] == 1, enumerate(X)))))[:,0], np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][1] == 1, enumerate(X)))))[:,1], color='red')
plt.scatter(np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][2] == 1, enumerate(X)))))[:,0], np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][2] == 1, enumerate(X)))))[:,1], color='green')
plt.show()
plt.clf()

# %%
X_train = [coord for sublist in X for coord in sublist]

Y_train_blue = list(map(lambda y: 1 if y[0] == 1 else 0, Y))

print(Y_train_blue[:5])
print(X_train[:5])
# Out:
# [0, 0, 0, 0, 0]
# [0.5354571169482636, 0.20893725845157385, 0.014639888587694605, 0.8132419363731835, -0.4771630412394534]

# %% [markdown]
# ### Multi Cross :
#         Linear Model x3 : KO
#         MLP (2, ?, ?, 3): OK

# %%
X = np.random.random((1000, 2)) * 2.0 - 1.0
Y = np.array([[1, 0, 0] if abs(p[0] % 0.5) <= 0.25 and abs(p[1] % 0.5) > 0.25 else [0, 1, 0] if abs(p[0] % 0.5) > 0.25 and abs(p[1] % 0.5) <= 0.25 else [0, 0, 1] for p in X])

# %%
plt.scatter(np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][0] == 1, enumerate(X)))))[:,0], np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][0] == 1, enumerate(X)))))[:,1], color='blue')
plt.scatter(np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][1] == 1, enumerate(X)))))[:,0], np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][1] == 1, enumerate(X)))))[:,1], color='red')
plt.scatter(np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][2] == 1, enumerate(X)))))[:,0], np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][2] == 1, enumerate(X)))))[:,1], color='green')
plt.show()
plt.clf()

# %% [markdown]
# ## Régression

# %% [markdown]
# ### Linear Simple 2D :
#         Linear Model : OK
#         MLP (1, 1)   : OK

# %%
X = np.array([
      [1],
      [2]
])
Y = np.array([
      2,
      3
])

# %%
plt.scatter(X,Y)
plt.show()
plt.clf()

# %% [markdown]
# ### Non Linear Simple 2D :
#         Linear Model    : OK
#         MLP (1, ?, 1)   : OK

# %%
X = np.array([
      [1],
      [2],
      [3]
])
Y = np.array([
      2,
      3,
      2.5
])

# %%
plt.scatter(X,Y)
plt.show()
plt.clf()

# %% [markdown]
# ### Linear Simple 3D :
#         Linear Model    : OK
#         MLP (2, 1)      : OK

# %%
X = np.array([
      [1, 1],
      [2, 2],
      [3, 1]
])
Y = np.array([
      2,
      3,
      2.5
])

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(X[:,0],X[:,1],Y)
plt.show()
plt.clf()

# %% [markdown]
# ### Linear Tricky 3D :
#         Linear Model    : OK
#         MLP (2, 1)      : OK

# %%
X = np.array([
      [1, 1],
      [2, 2],
      [3, 3]
])
Y = np.array([
      1,
      2,
      3
])

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(X[:,0],X[:,1],Y)
plt.show()
plt.clf()

# %% [markdown]
# ### Non Linear Simple 3D :
#         Linear Model       : KO
#         MLP (2, 2, 1)      : OK

# %%
X = np.array([
      [1, 0],
      [0, 1],
      [1, 1],
      [0, 0],
])
Y = np.array([
      2,
      1,
      -2,
      -1
])

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(X[:,0],X[:,1],Y)
plt.show()
plt.clf()
